# %% [markdown]
# ## Regression using LinearRegression

# %% [markdown]
# Importing Basic libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# Importing data file

# %%
df = pd.read_csv('Ecommerce Customers')
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %% [markdown]
# Dropping columns of no use

# %%
df.drop('Email', axis=1, inplace=True)
df.drop('Address', axis=1, inplace=True)
df.drop('Avatar', axis=1, inplace=True)

# %% [markdown]
# Defining X and y columns

# %%
X = df[['Avg. Session Length','Time on App','Time on Website','Length of Membership']]
y = df['Yearly Amount Spent']

# %% [markdown]
# Plotting each feature of X with y

# %%
for feature in X.columns:
    sns.lmplot(x = feature, y = 'Yearly Amount Spent', data = df, scatter_kws={'alpha':0.3})

# %% [markdown]
# Splitting Training and Test data from dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Regression using LinearRegression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# Generating Dataframe of actual vs predicted value

# %%
a = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred, 'y_test - y_pred':y_test - y_pred})
a
# Out:
#          Actual   Predicted  y_test - y_pred
# 90   449.070319  438.464881        10.605439
# 254  482.602467  489.661845        -7.059378
# 283  374.269675  370.069542         4.200133
# 445  513.153112  513.859056        -0.705944
# 461  502.771075  495.697999         7.073076
# ..          ...         ...              ...
# 372  385.152338  383.744509         1.407829
# 56   520.898794  524.168192        -3.269398
# 440  499.140152  500.682688        -1.542535
# 60   616.851523  606.787827        10.063696
# 208  412.012931  408.805191         3.207740
#
# [100 rows x 3 columns]

# %% [markdown]
# Plotting the dataframe

# %%
sns.lmplot(x = 'Actual', y = 'Predicted', data = a, scatter_kws={'alpha':0.3})

# %% [markdown]
# Evaluating the results

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R^2 Score:", r2)
# Out:
# MAE: 7.64567479891527
# MSE: 92.8901030449849
# RMSE: 9.637951185028118
# R^2 Score: 0.9861924261981548

# %% [markdown]
# Prediction (example)

# %%
new = np.array([[32, 10, 36, 3]])
new_predicted = model.predict(new)
new_predicted
# Out:
# C:\Users\spars\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([358.86953908])
